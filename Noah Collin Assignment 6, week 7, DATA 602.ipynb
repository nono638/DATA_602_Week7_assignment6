# %% [markdown]
# ### Noah Collin 10/9/2022

# %% [markdown]
# ## Assignment 6, week 7, DATA 602

# %% [markdown]
# In this assignment, you will practice loading data into your python environment. It is
# recommended that you use either google colab or juypter notebook, however, you may
# use any environment you prefer as long as you are using the pandas library.
# From the following link, choose two files to answer the questions below.
# https://github.com/data602sps/datasetspractice
# In addition, you will also search the internet to find two datasets to answer the
# questions below.
# Websites to find data:
# ● https://opendata.cityofnewyork.us/
# ● https://datasetsearch.research.google.com/
# ● https://www.kaggle.com/datasets
# ● http://archive.ics.uci.edu/ml/index.php
# ● https://data.gov/
# Q1. Load your dataset into python using the pandas library and save data into a
# dataframe named dfi (where i is one of your datasets, for a total of 4).
# Q2. Preview your data by calling your dataframe’s name. How many columns and rows
# do you see?
# Q3. Examine the shape of your data using the .shape command and the data types of
# your columns using .dtypes.
# Q4. Use .describe() on your data. What do you notice about your data? What does this
# command return?
# Q5. Use the .head() and .tail() command - what does this do?
# Extra Credit (3 pts)
# 1. Choose one of your datasets and remove the header information. (Can delete
# the row in excel, etc..)
# 2. Import the data into your environment using pandas. Display the .head() of your
# data showing no header information.
# 3. Using pandas, update the dataset to include the header information. Display the
# updated data using .head().
# Extra Credit (3 pts)
# 1. Import a “dirty” dataset from the internet into your environment. (Missing values,
# improper coding of columns, etc.)
# 2. Clean or “tidy” the data when loading into python using pandas.

# %%
import pandas as pd
print ("Pandas version: {}".format(pd.__version__) )
# Out:
# Pandas version: 1.4.2

# %% [markdown]
# #### Q1. Load your dataset into python using the pandas library and save data into a dataframe...
# and
# #### Q2. Preview your data by calling your dataframe’s name. How many columns and rows do you see?

# %%
weatherDF = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/weather.csv')
weatherDF
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %%
kobeURL = 'https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv'
kobeDF = pd.read_csv(kobeURL)
kobeDF.head()
# Out:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:47            Kobe Bryant makes 4-foot two point shot
# 1  ORL     1       1  9:07                          Kobe Bryant misses jumper
# 2  ORL     1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 3  ORL     1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4  ORL     1       1  7:03                    Kobe Bryant makes driving layup
#
#   basket
# 0      H
# 1      M
# 2      M
# 3      H
# 4      H

# %%
ThreeOneOneURL = 'https://data.cityofnewyork.us/resource/erm2-nwe9.csv'
ThreeOneOneDF = pd.read_csv(ThreeOneOneURL)
ThreeOneOneDF
# Out:
#      unique_key             created_date              closed_date agency  \
# 0      55633802  2022-10-08T12:00:00.000                      NaN   DSNY
# 1      55638898  2022-10-08T12:00:00.000                      NaN   DSNY
# 2      55632497  2022-10-08T12:00:00.000                      NaN   DSNY
# 3      55635557  2022-10-08T02:04:57.000  2022-10-08T02:04:57.000    DOT
# 4      55639870  2022-10-08T01:58:49.000                      NaN    DOT
# ..          ...                      ...                      ...    ...
# 995    55638235  2022-10-07T22:40:28.000  2022-10-08T00:21:06.000   NYPD
# 996    55637531  2022-10-07T22:40:15.000                      NaN   NYPD
# 997    55636962  2022-10-07T22:39:55.000  2022-10-07T22:50:47.000   NYPD
# 998    55637544  2022-10-07T22:39:53.000                      NaN   NYPD
# 999    55634424  2022-10-07T22:39:50.000  2022-10-07T22:58:01.000   NYPD
#
#                          agency_name           complaint_type  \
# ...

# %%
#annyoingliy, this dataset has no way to call straight from a URL, so you have to download it locally.  I tried using requests, googling it, etc

#'https://www.kaggle.com/datasets/rtatman/english-word-frequency/download?datasetVersionNumber=1'

WordFrequencyDF = pd.read_csv('unigram_freq.csv')
WordFrequencyDF
# Out:
#            word        count
# 0           the  23135851162
# 1            of  13151942776
# 2           and  12997637966
# 3            to  12136980858
# 4             a   9081174698
# ...         ...          ...
# 333328    gooek        12711
# 333329   gooddg        12711
# 333330  gooblle        12711
# 333331   gollgo        12711
# 333332    golgw        12711
#
# [333333 rows x 2 columns]

# %% [markdown]
# #### Q3. Preview your data by calling your dataframe’s name. How many columns and rows do you see?

# %%
dfs = [weatherDF, kobeDF, ThreeOneOneDF, WordFrequencyDF]
dfsNames = ['weatherDF', 'kobeDF', 'ThreeOneOneDF', 'WordFrequencyDF']

# %%
for i in range(len(dfs)):
    print("{}:  {}".format(dfsNames[i], dfs[i].shape) )
# Out:
# weatherDF:  (8719, 15)
# kobeDF:  (133, 6)
# ThreeOneOneDF:  (1000, 41)
# WordFrequencyDF:  (333333, 2)

# %% [markdown]
# #### Q4. Use .describe() on your data. What do you notice about your data? What does this command return? Q5. Use the .head() and .tail() command - what does this do? Extra Credit (3 pts)

# %%
for i in range(len(dfs)):
    print(dfsNames[i])
    print(dfs[i].describe())
    print()
# Out:
# weatherDF
#         Unnamed: 0    year        month          day         hour  \
# count  8719.000000  8719.0  8718.000000  8718.000000  8718.000000
# mean   4360.000000  2013.0     6.506538    15.679628    11.515715
# std    2517.102832     0.0     3.439961     8.768250     6.916846
# min       1.000000  2013.0     1.000000     1.000000     0.000000
# 25%    2180.500000  2013.0     4.000000     8.000000     6.000000
# 50%    4360.000000  2013.0     7.000000    16.000000    12.000000
# 75%    6539.500000  2013.0     9.000000    23.000000    18.000000
# max    8719.000000  2013.0    12.000000    31.000000    23.000000
#
#               temp         dewp        humid     wind_dir   wind_speed  \
# count  8718.000000  8718.000000  8718.000000  8486.000000  8718.000000
# mean     55.484942    41.794184    62.863333   193.194674     9.335732
# std      18.345817    19.619776    19.572699   110.541333    12.328261
# min      10.940000    -9.040000    13.950000     0.000000     0.000000
# ...

# %% [markdown]
# #### 1    Choose one of your datasets and remove the header information. (Can delete the row in excel, etc..)

# %%
KobeWithoutFirstRow = pd.read_csv(kobeURL, skiprows=1)

# %% [markdown]
# #### 2 Import the data into your environment using pandas. Display the .head() of your data showing no header information.

# %%
KobeWithoutFirstRow.head(3)
# Out:
#    ORL  1 1.1  9:47            Kobe Bryant makes 4-foot two point shot  H
# 0  ORL  1   1  9:07                          Kobe Bryant misses jumper  M
# 1  ORL  1   1  8:11                   Kobe Bryant misses 7-foot jumper  M
# 2  ORL  1   1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...  H

# %% [markdown]
# #### 3    Using pandas, update the dataset to include the header information. Display the updated data using .head(). Extra Credit (3 pts)

# %%
misplacedFirstRow = list(KobeWithoutFirstRow.columns)

# %%
KobeWithoutFirstRow.set_axis(list(kobeDF.columns),axis=1,inplace=True)

KobeWithoutFirstRow.head(3)
# Out:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:07                          Kobe Bryant misses jumper
# 1  ORL     1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 2  ORL     1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
#
#   basket
# 0      M
# 1      M
# 2      H

# %% [markdown]
# This works but the first row, which was previously mistook as the headers for the dataframe, is lost.  We saved it earlier so now we'll reinsert it:

# %%
#first put it as the last row with the -1 index
KobeWithoutFirstRow.loc[-1] = misplacedFirstRow

#The shift all the index by +1 so the -1 will become zero, then sort_index()
KobeWithoutFirstRow.index = KobeWithoutFirstRow.index +1
KobeWithoutFirstRow = KobeWithoutFirstRow.sort_index()
KobeWithoutFirstRow.head()


#inspiration drawn from here:
#    https://stackoverflow.com/questions/24284342/insert-a-row-to-pandas-dataframe
# Out:
#     vs game quarter  time                                        description  \
# 0  ORL    1     1.1  9:47            Kobe Bryant makes 4-foot two point shot
# 1  ORL    1       1  9:07                          Kobe Bryant misses jumper
# 2  ORL    1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 3  ORL    1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4  ORL    1       1  7:03                    Kobe Bryant makes driving layup
#
#   basket
# 0      H
# 1      M
# 2      M
# 3      H
# 4      H

# %% [markdown]
# #### 4    Import a “dirty” dataset from the internet into your environment. (Missing values, improper coding of columns, etc.)

# %% [markdown]
# I'm going to use the already loaded 3-1-1 dataset above.

# %% [markdown]
# #### 5    Clean or “tidy” the data when loading into python using pandas.

# %% [markdown]
# The 3-1-1 dataset has many null values.  It's actually off the NYC site, a city known for its dirtiness...<p>The dataset has many null values

# %%
ThreeOneOneDF.isnull().sum().sort_values(ascending=False)
# Out:
# due_date                          1000
# road_ramp                         1000
# taxi_company_borough               999
# facility_type                      999
# vehicle_type                       999
# bridge_highway_direction           997
# bridge_highway_name                994
# bridge_highway_segment             994
# taxi_pick_up_location              987
# closed_date                        539
# resolution_description             461
# resolution_action_updated_date     275
# landmark                           113
# bbl                                 97
# city                                59
# intersection_street_1               57
# intersection_street_2               56
# cross_street_1                      41
# cross_street_2                      40
# location_type                       23
# incident_address                    10
# street_name                         10
# descriptor                           9
# longitude                            6
# ...

# %%
ThreeOneOneDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      1000 non-null   int64
#  1   created_date                    1000 non-null   object
#  2   closed_date                     461 non-null    object
#  3   agency                          1000 non-null   object
#  4   agency_name                     1000 non-null   object
#  5   complaint_type                  1000 non-null   object
#  6   descriptor                      991 non-null    object
#  7   location_type                   977 non-null    object
#  8   incident_zip                    994 non-null    float64
#  9   incident_address                990 non-null    object
#  10  street_name                     990 non-null    object
#  11  cross_street_1                  959 non-null    object
# ...

# %% [markdown]
# We can drop some columns that are, for example, 100% null values or have a high percentage of null values.  Some columns are resonable that it has a lot of null values because that column only applies to a small subset of suituations.  We could make a "special note" column and consolidate these nearly one-off columns as well.

# %%
columnsToDrop = ['due_date', #dropping columns that have 98%+ null values
                 'road_ramp', 
                 'taxi_company_borough',
                 'facility_type',
                 'vehicle_type',
                 'bridge_highway_direction',
                 'bridge_highway_name',
                 'bridge_highway_segment',
                 'taxi_pick_up_location']

# %% [markdown]
# Drop several columns:

# %%
ThreeOneOneCleaned = ThreeOneOneDF
for col in columnsToDrop:
    ThreeOneOneCleaned = ThreeOneOneCleaned.drop(col, axis=1)

# %%
ThreeOneOneCleaned.columns.sort_values()
# Out:
# Index(['address_type', 'agency', 'agency_name', 'bbl', 'borough', 'city',
#        'closed_date', 'community_board', 'complaint_type', 'created_date',
#        'cross_street_1', 'cross_street_2', 'descriptor', 'incident_address',
#        'incident_zip', 'intersection_street_1', 'intersection_street_2',
#        'landmark', 'latitude', 'location', 'location_type', 'longitude',
#        'open_data_channel_type', 'park_borough', 'park_facility_name',
#        'resolution_action_updated_date', 'resolution_description', 'status',
#        'street_name', 'unique_key', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane'],
#       dtype='object')

# %% [markdown]
# Below, I've replaced the NaN values in the "closed_date" column with the string "<i>not closed<i>" so that there's fewer null values.

# %%
#ThreeOneOneCleaned['closed_date'].value_counts()

# %%
ThreeOneOneCleaned.closed_date.fillna("not closed", inplace=True)

# %%
ThreeOneOneCleaned.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    55633802  2022-10-08T12:00:00.000               not closed   DSNY
# 1    55638898  2022-10-08T12:00:00.000               not closed   DSNY
# 2    55632497  2022-10-08T12:00:00.000               not closed   DSNY
# 3    55635557  2022-10-08T02:04:57.000  2022-10-08T02:04:57.000    DOT
# 4    55639870  2022-10-08T01:58:49.000               not closed    DOT
#
#                     agency_name     complaint_type         descriptor  \
# 0      Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 1      Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2      Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 3  Department of Transportation   Street Condition            Pothole
# 4  Department of Transportation   Street Condition            Pothole
#
#   location_type  incident_zip      incident_address  ...           bbl  \
# ...

# %% [markdown]
# There are ten columns with a null incident_address, let's investigate

# %%
ThreeOneOneCleaned[ThreeOneOneCleaned[ 'incident_address'].isnull()]
# Out:
#      unique_key             created_date              closed_date agency  \
# 78     55636366  2022-10-08T00:55:19.000               not closed   NYPD
# 130    55640745  2022-10-08T00:46:00.000               not closed    DOT
# 199    55633460  2022-10-08T00:36:37.000               not closed    DOT
# 200    55631718  2022-10-08T00:36:00.000               not closed    DOT
# 295    55636365  2022-10-08T00:22:32.000               not closed   NYPD
# 301    55640226  2022-10-08T00:21:25.000               not closed   NYPD
# 617    55638945  2022-10-07T23:34:13.000               not closed    DHS
# 708    55637635  2022-10-07T23:19:57.000  2022-10-08T00:42:22.000   NYPD
# 793    55637647  2022-10-07T23:07:39.000               not closed   NYPD
# 947    55640707  2022-10-07T22:47:00.000               not closed    DOT
#
#                          agency_name              complaint_type  \
# 78   New York City Police Department                  Encampment
# ...

# %% [markdown]
# I suppose some of these incident happened in the subway, which obvioouslly wouldnt' have and addrees, and others are for the DOT which can use the coordinates, so I guess we'll leave these entries alone

# %% [markdown]
# ##### Although the dataframe has lots of missing values, it does seem that the dataset is relatively complete after a cursory look through it.  It's just organized in such a way that there are columns that only pertrain to certian circumstances for 311 and are likely only useful to certain downstream departments like the Department of Transportation or the NYCPD.
